# %%
# IMPLEMENTING SHOR'S ALGORITHM CLASSICALLY

# %%
N = 15 # The number we want to factor
a = 13 # taking a number co-prime with N

# %%
import math
math.gcd(a, N) # Checking if a, N are co-prime
# Out:
# 1

# %%
# Plot the function a^x (mod N)

import matplotlib.pyplot as plt
X = list(range(N)) # List of numbers from 0 to N-1
Y = [a**n % N for n in X] # List of numbers a^x (mod N)

plt.plot(X, Y)
plt.xlabel ('X')
plt.ylabel(f'{a}^X (mod{N})')
plt.show()

# %%
r = X[Y[1:].index(1)+1]
# Y[1:] creates a new list with element of Y starting from index 1, i.e. without Y[0]
# .index(1) returns the index of new list Y[1:] where we first see the value "1"
# We do .index(1)+1 to match the index of X with Y[1:], i.e. ignoring the value X[0]
print(f'r = {r}') # r is the period
# Out:
# r = 4

# %%
# We write the full algorithm of Shor

if r % 2 == 0: # i.e. if r is even
    x = (a**(r/2.)) % N # "." after 2 ensures floating values
    print(f'x = {x}')
    if ((x+1) % N) != 0:
        print(f'Factors of {N} are {math.gcd((int(x)+1), N)} and {math.gcd((int(x)-1), N)}')
    else:
        print("x+1 is 0 (mod N)")
else:
    print(f'r = {r} is odd')
# Out:
# x = 4.0
# Factors of 15 are 5 and 3

# %%
# Let us try for another number

# %%
N = 91 # The number we want to factor
a = 66 # taking a number co-prime with N

# %%
import math
math.gcd(a, N) # Checking if a, N are co-prime
# Out:
# 1

# %%
# Plot the function a^x (mod N)

import matplotlib.pyplot as plt
X = list(range(N)) # List of numbers from 0 to N-1
Y = [a**n % N for n in X] # List of numbers a^x (mod N)

plt.plot(X, Y)
plt.xlabel ('X')
plt.ylabel(f'{a}^X (mod{N})')
plt.show()

# %%
r = X[Y[1:].index(1)+1]
print(f'r = {r}') # r is the period
# Out:
# r = 6

# %%
# We write the full algorithm of Shor

if r % 2 == 0: # i.e. if r is even
    x = (a**(r/2.)) % N # "." after 2 ensures floating values
    print(f'x = {x}')
    if ((x+1) % N) != 0:
        print(f'Factors of {N} are {math.gcd((int(x)+1), N)} and {math.gcd((int(x)-1), N)}')
    else:
        print("x+1 is 0 (mod N)")
else:
    print(f'r = {r} is odd')
# Out:
# x = 27.0
# Factors of 91 are 7 and 13

# %%
#######################################

# %%
# Calculating the coefficients in |x> register after step-4 (see theory)

import numpy as np
pi = np.pi
for y in range(16):
    coeff = np.exp(-1j*y*3*pi/8) + np.exp(-1j*y*7*pi/8) + np.exp(-1j*y*11*pi/8) + np.exp(-1j*y*15*pi/8)
    if abs(coeff) < 1e-10:
        coeff = 0 # if coeff is very small, i.e. less than e^-10, then we presume it to be 0
    print (f'Coeff of |{y}> : {coeff}')
# Out:
# Coeff of |0> : (4+0j)
# Coeff of |1> : 0
# Coeff of |2> : 0
# Coeff of |3> : 0
# Coeff of |4> : (-5.757077917265737e-15+4j)
# Coeff of |5> : 0
# Coeff of |6> : 0
# Coeff of |7> : 0
# Coeff of |8> : (-4-1.1514155834531474e-14j)
# Coeff of |9> : 0
# Coeff of |10> : 0
# Coeff of |11> : 0
# Coeff of |12> : (1.2840221971949557e-15-4j)
# Coeff of |13> : 0
# Coeff of |14> : 0
# Coeff of |15> : 0

# %%
# We get: 
# coeff of |0> is 4
# coeff of |4> is 4i
# coeff of |8> is -4
# coeff of |12> is -4i

# %%
# Calculation for N=105

# %%
import numpy as np
pi = np.pi
for y in range(128):
    coeff = np.exp(-1j*y*pi/64) + np.exp(-1j*y*5*pi/64) + np.exp(-1j*y*9*pi/64) + np.exp(-1j*y*13*pi/64) + np.exp(-1j*y*17*pi/64) + np.exp(-1j*y*21*pi/64) + np.exp(-1j*y*25*pi/64) + np.exp(-1j*y*29*pi/64) + np.exp(-1j*y*33*pi/64) + np.exp(-1j*y*37*pi/64) + np.exp(-1j*y*41*pi/64) + np.exp(-1j*y*45*pi/64) + np.exp(-1j*y*49*pi/64) + np.exp(-1j*y*53*pi/64) + np.exp(-1j*y*57*pi/64) + np.exp(-1j*y*61*pi/64) + np.exp(-1j*y*65*pi/64) + np.exp(-1j*y*69*pi/64) + np.exp(-1j*y*73*pi/64) + np.exp(-1j*y*77*pi/64) + np.exp(-1j*y*81*pi/64) + np.exp(-1j*y*85*pi/64) + np.exp(-1j*y*89*pi/64) + np.exp(-1j*y*93*pi/64) + np.exp(-1j*y*97*pi/64) + np.exp(-1j*y*101*pi/64) + np.exp(-1j*y*105*pi/64) + np.exp(-1j*y*109*pi/64) + np.exp(-1j*y*113*pi/64) + np.exp(-1j*y*117*pi/64) + np.exp(-1j*y*121*pi/64) + np.exp(-1j*y*125*pi/64)
    if abs(coeff) < 1e-10:
        coeff = 0 # if coeff is very small, i.e. less than e^-10, then we presume it to be 0
    print (f'Coeff of |{y}> : {coeff}')
# Out:
# Coeff of |0> : (32+0j)
# Coeff of |1> : 0
# Coeff of |2> : 0
# Coeff of |3> : 0
# Coeff of |4> : 0
# Coeff of |5> : 0
# Coeff of |6> : 0
# Coeff of |7> : 0
# Coeff of |8> : 0
# Coeff of |9> : 0
# Coeff of |10> : 0
# Coeff of |11> : 0
# Coeff of |12> : 0
# Coeff of |13> : 0
# Coeff of |14> : 0
# Coeff of |15> : 0
# Coeff of |16> : 0
# Coeff of |17> : 0
# Coeff of |18> : 0
# Coeff of |19> : 0
# Coeff of |20> : 0
# Coeff of |21> : 0
# Coeff of |22> : 0
# Coeff of |23> : 0
# Coeff of |24> : 0
# Coeff of |25> : 0
# Coeff of |26> : 0
# Coeff of |27> : 0
# Coeff of |28> : 0
# Coeff of |29> : 0
# Coeff of |30> : 0
# Coeff of |31> : 0
# Coeff of |32> : (1.50089749945057e-13-32j)
# Coeff of |33> : 0
# Coeff of |34> : 0
# Coeff of |35> : 0
# Coeff of |36> : 0
# Coeff of |37> : 0
# Coeff of |38> : 0
# Coeff of |39> : 0
# Coeff of |40> : 0
# Coeff of |41> : 0
# Coeff of |42> : 0
# Coeff of |43> : 0
# Coeff of |44> : 0
# Coeff of |45> : 0
# Coeff of |46> : 0
# Coeff of |47> : 0
# Coeff of |48> : 0
# Coeff of |49> : 0
# Coeff of |50> : 0
# Coeff of |51> : 0
# Coeff of |52> : 0
# Coeff of |53> : 0
# Coeff of |54> : 0
# Coeff of |55> : 0
# Coeff of |56> : 0
# Coeff of |57> : 0
# Coeff of |58> : 0
# Coeff of |59> : 0
# Coeff of |60> : 0
# Coeff of |61> : 0
# Coeff of |62> : 0
# Coeff of |63> : 0
# Coeff of |64> : (-32-3.00179499890114e-13j)
# Coeff of |65> : 0
# Coeff of |66> : 0
# Coeff of |67> : 0
# Coeff of |68> : 0
# Coeff of |69> : 0
# Coeff of |70> : 0
# Coeff of |71> : 0
# Coeff of |72> : 0
# Coeff of |73> : 0
# Coeff of |74> : 0
# Coeff of |75> : 0
# Coeff of |76> : 0
# Coeff of |77> : 0
# Coeff of |78> : 0
# Coeff of |79> : 0
# Coeff of |80> : 0
# Coeff of |81> : 0
# Coeff of |82> : 0
# Coeff of |83> : 0
# Coeff of |84> : 0
# Coeff of |85> : 0
# Coeff of |86> : 0
# Coeff of |87> : 0
# Coeff of |88> : 0
# Coeff of |89> : 0
# Coeff of |90> : 0
# Coeff of |91> : 0
# Coeff of |92> : 0
# Coeff of |93> : 0
# Coeff of |94> : 0
# Coeff of |95> : 0
# Coeff of |96> : (-3.4013512579235533e-13+32j)
# Coeff of |97> : 0
# Coeff of |98> : 0
# Coeff of |99> : 0
# Coeff of |100> : 0
# Coeff of |101> : 0
# Coeff of |102> : 0
# Coeff of |103> : 0
# Coeff of |104> : 0
# Coeff of |105> : 0
# Coeff of |106> : 0
# Coeff of |107> : 0
# Coeff of |108> : 0
# Coeff of |109> : 0
# Coeff of |110> : 0
# Coeff of |111> : 0
# Coeff of |112> : 0
# Coeff of |113> : 0
# Coeff of |114> : 0
# Coeff of |115> : 0
# Coeff of |116> : 0
# Coeff of |117> : 0
# Coeff of |118> : 0
# Coeff of |119> : 0
# Coeff of |120> : 0
# Coeff of |121> : 0
# Coeff of |122> : 0
# Coeff of |123> : 0
# Coeff of |124> : 0
# Coeff of |125> : 0
# Coeff of |126> : 0
# Coeff of |127> : 0
